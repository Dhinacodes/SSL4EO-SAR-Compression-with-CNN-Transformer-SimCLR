# %%
import zarr
import numpy as np

# Specify the folder where the Zarr dataset should be saved
zarr_store = zarr.open_group(r"D:\Eval.AI\train\ssl4eos12_train_seasonal_data_000001.zarr", mode='w')

# Create a dataset with chunking
zarr_store.create_dataset("images", shape=(1000, 256, 256, 3), chunks=(10, 256, 256, 3), dtype=np.uint8)

# Store some random samples
zarr_store["images"][:10] = np.random.randint(0, 255, (10, 256, 256, 3), dtype=np.uint8)

print("Zarr dataset successfully saved in a folder!")
# Out:
# Zarr dataset successfully saved in a folder!

# %%
# !pip install zarr xarray numpy imageio dask
# Out:
# Requirement already satisfied: zarr in c:\users\dhina\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (2.18.3)
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: C:\Users\Dhina\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Collecting xarray
#   Obtaining dependency information for xarray from https://files.pythonhosted.org/packages/91/fd/973deafd9f87085136a58573600646b408ae7af47859f35151f0d83d5090/xarray-2025.3.1-py3-none-any.whl.metadata
#   Downloading xarray-2025.3.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: numpy in c:\users\dhina\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (1.26.3)
# Requirement already satisfied: imageio in c:\users\dhina\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (2.34.0)
# Collecting dask
#   Obtaining dependency information for dask from https://files.pythonhosted.org/packages/bd/8a/3609033a4bfd7c9b3e8a4e8a5d6e318dfc06ab2e2d3b5cb0e01a60458858/dask-2025.3.0-py3-none-any.whl.metadata
#   Downloading dask-2025.3.0-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: asciitree in c:\users\dhina\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from zarr) (0.3.3)
# Requirement already satisfied: numcodecs>=0.10.0 in c:\users\dhina\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from zarr) (0.13.1)
# Requirement already satisfied: fasteners in c:\users\dhina\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from zarr) (0.19)
# Requirement already satisfied: packaging>=23.2 in c:\users\dhina\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from xarray) (23.2)
# Requirement already satisfied: pandas>=2.1 in c:\users\dhina\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from xarray) (2.2.3)
# Requirement already satisfied: pillow>=8.3.2 in c:\users\dhina\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from imageio) (9.2.0)
# Requirement already satisfied: click>=8.1 in c:\users\dhina\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from dask) (8.1.3)
# Collecting cloudpickle>=3.0.0 (from dask)
#   Obtaining dependency information for cloudpickle>=3.0.0 from https://files.pythonhosted.org/packages/7e/e8/64c37fadfc2816a7701fa8a6ed8d87327c7d54eacfbfb6edab14a2f2be75/cloudpickle-3.1.1-py3-none-any.whl.metadata
#   Downloading cloudpickle-3.1.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: fsspec>=2021.09.0 in c:\users\dhina\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from dask) (2023.10.0)
# Collecting partd>=1.4.0 (from dask)
#   Obtaining dependency information for partd>=1.4.0 from https://files.pythonhosted.org/packages/71/e7/40fb618334dcdf7c5a316c0e7343c5cd82d3d866edc100d98e29bc945ecd/partd-1.4.2-py3-none-any.whl.metadata
#   Downloading partd-1.4.2-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\dhina\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from dask) (6.0.1)
# Requirement already satisfied: toolz>=0.10.0 in c:\users\dhina\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from dask) (0.12.1)
# Requirement already satisfied: importlib_metadata>=4.13.0 in c:\users\dhina\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from dask) (7.0.1)
# Requirement already satisfied: colorama in c:\users\dhina\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from click>=8.1->dask) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\users\dhina\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from importlib_metadata>=4.13.0->dask) (3.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dhina\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas>=2.1->xarray) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dhina\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas>=2.1->xarray) (2023.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dhina\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas>=2.1->xarray) (2023.3)
# Collecting locket (from partd>=1.4.0->dask)
#   Obtaining dependency information for locket from https://files.pythonhosted.org/packages/db/bc/83e112abc66cd466c6b83f99118035867cecd41802f8d044638aa78a106e/locket-1.0.0-py2.py3-none-any.whl.metadata
#   Downloading locket-1.0.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: six>=1.5 in c:\users\dhina\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.8.2->pandas>=2.1->xarray) (1.16.0)
# Downloading xarray-2025.3.1-py3-none-any.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.3 MB 10.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 0.7/1.3 MB 9.3 MB/s eta 0:00:01
#    -------------------------------------- - 1.2/1.3 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.3/1.3 MB 8.1 MB/s eta 0:00:00
# Downloading dask-2025.3.0-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    -------------- ------------------------- 0.5/1.4 MB 16.2 MB/s eta 0:00:01
#    --------------------------- ------------ 1.0/1.4 MB 12.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.3/1.4 MB 10.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 9.1 MB/s eta 0:00:00
# Downloading cloudpickle-3.1.1-py3-none-any.whl (20 kB)
# Downloading partd-1.4.2-py3-none-any.whl (18 kB)
# Downloading locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Installing collected packages: locket, cloudpickle, partd, xarray, dask
# Successfully installed cloudpickle-3.1.1 dask-2025.3.0 locket-1.0.0 partd-1.4.2 xarray-2025.3.1

# %%
import xarray as xr
ds = xr.open_zarr('train/ssl4eos12_train_seasonal_data_000001.zarr.zip')  # load xarray dataset
data = ds.bands.values  # load numpy array with dims [B, T, C, H, W]

# %%
print(data.shape)  # Should show (B, T, C, H, W)
# Out:
# (64, 4, 2, 264, 264)

# %%
import xarray as xr
import numpy as np
import os
from PIL import Image

# Load the xarray dataset
ds = xr.open_zarr('train/ssl4eos12_train_seasonal_data_000001.zarr.zip')

# Extract the bands data as a NumPy array with shape [B, T, C, H, W]
data = ds.bands.values  

# Ensure the output directory exists
output_dir = os.path.join("train", "output")
os.makedirs(output_dir, exist_ok=True)

def transform_image(img, offset=1000):
    """Applies contrast stretching and normalization to the input image."""
    img = img - offset  # Apply offset correction

    # Compute 2nd and 98th percentile for contrast adjustment
    Q2, Q98 = np.quantile(img, [0.02, 0.98])

    # Adjust outlier values
    img = np.where(img >= Q2, img, Q2 + (img - Q2) * 0.5)
    img = np.where(img <= Q98, img, Q98 + (img - Q98) * 0.5)

    # Compute additional quantiles for normalization
    Q02, Q50, Q998 = np.quantile(img, [0.002, 0.5, 0.998])

    # Determine normalization limits
    U = max(2000, Q998)
    L = 0 if Q50 < 1000 else Q02

    # Normalize to 0-255 range
    img = (img - L) / (U - L) * 255
    img = np.clip(img, 0, 255)  # Ensure values stay in range

    return img.astype(np.uint8)

# Loop through each image and save as PNG
for b in range(data.shape[0]):  # B: batch index
    for t in range(data.shape[1]):  # T: time index
        for c in range(data.shape[2]):  # C: channel index
            img = transform_image(data[b, t, c])  # Transform the image
            img_path = os.path.join(output_dir, f"image_B{b}_T{t}_C{c}.png")  # Naming convention
            Image.fromarray(img).save(img_path)  # Save as PNG

print(f"Images saved in: {output_dir}")
# Out:
# Images saved in: train\output

# %%
import os
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
import xarray as xr

def normalize(img):
    """Normalize array to 0–255 for image saving."""
    img_min = img.min()
    img_max = img.max()
    return ((img - img_min) / (img_max - img_min + 1e-6) * 255).astype(np.uint8)

def save_image(img_array, path):
    """Save an image array to the given path."""
    img = Image.fromarray(img_array)
    img.save(path)

def extract_and_save_all_images(zarr_path, output_dir, band_indices=[0, 1, 2], max_timestamps=4):
    """Extracts all samples and up to 4 time steps from Sentinel-2 Zarr data, saves as images."""
    # Load dataset
    ds = xr.open_zarr(zarr_path)
    data = ds.bands.values  # shape: [B, T, C, H, W]
    B, T, C, H, W = data.shape
    print(f"Loaded data shape: {data.shape}")

    os.makedirs(output_dir, exist_ok=True)

    for b in range(B):
        for t in range(min(T, max_timestamps)):
            # Extract selected bands
            image = data[b, t, band_indices, :, :]  # shape: [3, H, W]

            # Normalize each band
            normalized_image = np.stack([normalize(image[i]) for i in range(len(band_indices))], axis=-1)

            # Save image
            filename = f"sample_{b}_time_{t}.png"
            save_path = os.path.join(output_dir, filename)
            save_image(normalized_image, save_path)

            print(f"Saved {filename}")

    print("All images extracted and saved.")

# === Run the function ===
zarr_file_path = r'D:\Eval.AI\train\ssl4eos12_train_seasonal_data_000001.zarr'
output_folder = "output_images"

extract_and_save_all_images(zarr_file_path, output_folder)
# Out:
# Loaded data shape: (64, 4, 3, 264, 264)
# Saved sample_0_time_0.png
# Saved sample_0_time_1.png
# Saved sample_0_time_2.png
# Saved sample_0_time_3.png
# Saved sample_1_time_0.png
# Saved sample_1_time_1.png
# Saved sample_1_time_2.png
# Saved sample_1_time_3.png
# Saved sample_2_time_0.png
# Saved sample_2_time_1.png
# Saved sample_2_time_2.png
# Saved sample_2_time_3.png
# Saved sample_3_time_0.png
# Saved sample_3_time_1.png
# Saved sample_3_time_2.png
# Saved sample_3_time_3.png
# Saved sample_4_time_0.png
# Saved sample_4_time_1.png
# Saved sample_4_time_2.png
# Saved sample_4_time_3.png
# Saved sample_5_time_0.png
# Saved sample_5_time_1.png
# Saved sample_5_time_2.png
# Saved sample_5_time_3.png
# Saved sample_6_time_0.png
# Saved sample_6_time_1.png
# Saved sample_6_time_2.png
# Saved sample_6_time_3.png
# Saved sample_7_time_0.png
# Saved sample_7_time_1.png
# Saved sample_7_time_2.png
# Saved sample_7_time_3.png
# Saved sample_8_time_0.png
# Saved sample_8_time_1.png
# Saved sample_8_time_2.png
# Saved sample_8_time_3.png
# Saved sample_9_time_0.png
# Saved sample_9_time_1.png
# Saved sample_9_time_2.png
# Saved sample_9_time_3.png
# Saved sample_10_time_0.png
# Saved sample_10_time_1.png
# Saved sample_10_time_2.png
# Saved sample_10_time_3.png
# Saved sample_11_time_0.png
# Saved sample_11_time_1.png
# Saved sample_11_time_2.png
# Saved sample_11_time_3.png
# Saved sample_12_time_0.png
# Saved sample_12_time_1.png
# Saved sample_12_time_2.png
# Saved sample_12_time_3.png
# Saved sample_13_time_0.png
# Saved sample_13_time_1.png
# Saved sample_13_time_2.png
# Saved sample_13_time_3.png
# Saved sample_14_time_0.png
# Saved sample_14_time_1.png
# Saved sample_14_time_2.png
# Saved sample_14_time_3.png
# Saved sample_15_time_0.png
# Saved sample_15_time_1.png
# Saved sample_15_time_2.png
# Saved sample_15_time_3.png
# Saved sample_16_time_0.png
# Saved sample_16_time_1.png
# Saved sample_16_time_2.png
# Saved sample_16_time_3.png
# Saved sample_17_time_0.png
# Saved sample_17_time_1.png
# Saved sample_17_time_2.png
# Saved sample_17_time_3.png
# Saved sample_18_time_0.png
# Saved sample_18_time_1.png
# Saved sample_18_time_2.png
# Saved sample_18_time_3.png
# Saved sample_19_time_0.png
# Saved sample_19_time_1.png
# Saved sample_19_time_2.png
# Saved sample_19_time_3.png
# Saved sample_20_time_0.png
# Saved sample_20_time_1.png
# Saved sample_20_time_2.png
# Saved sample_20_time_3.png
# Saved sample_21_time_0.png
# Saved sample_21_time_1.png
# Saved sample_21_time_2.png
# Saved sample_21_time_3.png
# Saved sample_22_time_0.png
# Saved sample_22_time_1.png
# Saved sample_22_time_2.png
# Saved sample_22_time_3.png
# Saved sample_23_time_0.png
# Saved sample_23_time_1.png
# Saved sample_23_time_2.png
# Saved sample_23_time_3.png
# Saved sample_24_time_0.png
# Saved sample_24_time_1.png
# Saved sample_24_time_2.png
# Saved sample_24_time_3.png
# Saved sample_25_time_0.png
# Saved sample_25_time_1.png
# Saved sample_25_time_2.png
# Saved sample_25_time_3.png
# Saved sample_26_time_0.png
# Saved sample_26_time_1.png
# Saved sample_26_time_2.png
# Saved sample_26_time_3.png
# Saved sample_27_time_0.png
# Saved sample_27_time_1.png
# Saved sample_27_time_2.png
# Saved sample_27_time_3.png
# Saved sample_28_time_0.png
# Saved sample_28_time_1.png
# Saved sample_28_time_2.png
# Saved sample_28_time_3.png
# Saved sample_29_time_0.png
# Saved sample_29_time_1.png
# Saved sample_29_time_2.png
# Saved sample_29_time_3.png
# Saved sample_30_time_0.png
# Saved sample_30_time_1.png
# Saved sample_30_time_2.png
# Saved sample_30_time_3.png
# Saved sample_31_time_0.png
# Saved sample_31_time_1.png
# Saved sample_31_time_2.png
# Saved sample_31_time_3.png
# Saved sample_32_time_0.png
# Saved sample_32_time_1.png
# Saved sample_32_time_2.png
# Saved sample_32_time_3.png
# Saved sample_33_time_0.png
# Saved sample_33_time_1.png
# Saved sample_33_time_2.png
# Saved sample_33_time_3.png
# Saved sample_34_time_0.png
# Saved sample_34_time_1.png
# Saved sample_34_time_2.png
# Saved sample_34_time_3.png
# Saved sample_35_time_0.png
# Saved sample_35_time_1.png
# Saved sample_35_time_2.png
# Saved sample_35_time_3.png
# Saved sample_36_time_0.png
# Saved sample_36_time_1.png
# Saved sample_36_time_2.png
# Saved sample_36_time_3.png
# Saved sample_37_time_0.png
# Saved sample_37_time_1.png
# Saved sample_37_time_2.png
# Saved sample_37_time_3.png
# Saved sample_38_time_0.png
# Saved sample_38_time_1.png
# Saved sample_38_time_2.png
# Saved sample_38_time_3.png
# Saved sample_39_time_0.png
# Saved sample_39_time_1.png
# Saved sample_39_time_2.png
# Saved sample_39_time_3.png
# Saved sample_40_time_0.png
# Saved sample_40_time_1.png
# Saved sample_40_time_2.png
# Saved sample_40_time_3.png
# Saved sample_41_time_0.png
# Saved sample_41_time_1.png
# Saved sample_41_time_2.png
# Saved sample_41_time_3.png
# Saved sample_42_time_0.png
# Saved sample_42_time_1.png
# Saved sample_42_time_2.png
# Saved sample_42_time_3.png
# Saved sample_43_time_0.png
# Saved sample_43_time_1.png
# Saved sample_43_time_2.png
# Saved sample_43_time_3.png
# Saved sample_44_time_0.png
# Saved sample_44_time_1.png
# Saved sample_44_time_2.png
# Saved sample_44_time_3.png
# Saved sample_45_time_0.png
# Saved sample_45_time_1.png
# Saved sample_45_time_2.png
# Saved sample_45_time_3.png
# Saved sample_46_time_0.png
# Saved sample_46_time_1.png
# Saved sample_46_time_2.png
# Saved sample_46_time_3.png
# Saved sample_47_time_0.png
# Saved sample_47_time_1.png
# Saved sample_47_time_2.png
# Saved sample_47_time_3.png
# Saved sample_48_time_0.png
# Saved sample_48_time_1.png
# Saved sample_48_time_2.png
# Saved sample_48_time_3.png
# Saved sample_49_time_0.png
# Saved sample_49_time_1.png
# Saved sample_49_time_2.png
# Saved sample_49_time_3.png
# Saved sample_50_time_0.png
# Saved sample_50_time_1.png
# Saved sample_50_time_2.png
# Saved sample_50_time_3.png
# Saved sample_51_time_0.png
# Saved sample_51_time_1.png
# Saved sample_51_time_2.png
# Saved sample_51_time_3.png
# Saved sample_52_time_0.png
# Saved sample_52_time_1.png
# Saved sample_52_time_2.png
# Saved sample_52_time_3.png
# Saved sample_53_time_0.png
# Saved sample_53_time_1.png
# Saved sample_53_time_2.png
# Saved sample_53_time_3.png
# Saved sample_54_time_0.png
# Saved sample_54_time_1.png
# Saved sample_54_time_2.png
# Saved sample_54_time_3.png
# Saved sample_55_time_0.png
# Saved sample_55_time_1.png
# Saved sample_55_time_2.png
# Saved sample_55_time_3.png
# Saved sample_56_time_0.png
# Saved sample_56_time_1.png
# Saved sample_56_time_2.png
# Saved sample_56_time_3.png
# Saved sample_57_time_0.png
# Saved sample_57_time_1.png
# Saved sample_57_time_2.png
# Saved sample_57_time_3.png
# Saved sample_58_time_0.png
# Saved sample_58_time_1.png
# Saved sample_58_time_2.png
# Saved sample_58_time_3.png
# Saved sample_59_time_0.png
# Saved sample_59_time_1.png
# Saved sample_59_time_2.png
# Saved sample_59_time_3.png
# Saved sample_60_time_0.png
# Saved sample_60_time_1.png
# Saved sample_60_time_2.png
# Saved sample_60_time_3.png
# Saved sample_61_time_0.png
# Saved sample_61_time_1.png
# Saved sample_61_time_2.png
# Saved sample_61_time_3.png
# Saved sample_62_time_0.png
# Saved sample_62_time_1.png
# Saved sample_62_time_2.png
# Saved sample_62_time_3.png
# Saved sample_63_time_0.png
# Saved sample_63_time_1.png
# Saved sample_63_time_2.png
# Saved sample_63_time_3.png
# All images extracted and saved.

# %%
import os
import numpy as np
import xarray as xr
import cv2
from skimage.filters import sobel
from scipy.ndimage import gaussian_filter
from tqdm import tqdm

# ---------- Configuration ----------
ZARR_PATH = 'D:\Eval.AI\train\ssl4eos12_train_seasonal_data_000001.zarr'
OUTPUT_DIR = './embeddings'
DOWNSAMPLED_SIZE = (64, 64)  # H, W
os.makedirs(OUTPUT_DIR, exist_ok=True)

# ---------- Load Data ----------
ds = xr.open_zarr(ZARR_PATH)
data = ds['bands'].values  # shape: [B, T=4, C=2, H, W]
print("Data shape:", data.shape)

# ---------- Helper Functions ----------
def normalize(img):
    img = img.astype(np.float32)
    return (img - img.min()) / (img.max() - img.min() + 1e-6)

def bilateral_denoise(img):
    img = normalize(img)
    return cv2.bilateralFilter((img * 255).astype(np.uint8), d=5, sigmaColor=75, sigmaSpace=75)

def extract_edge_map(img):
    return sobel(normalize(img))

def downsample(img, size):
    return cv2.resize(img, size[::-1], interpolation=cv2.INTER_AREA)

# ---------- Main Pipeline ----------
embeddings = []
for i in tqdm(range(data.shape[0])):  # For each cube
    temporal_images = []

    for t in range(4):  # For each season
        vv = data[i, t, 0]  # VV
        vh = data[i, t, 1]  # VH

        vv_denoised = bilateral_denoise(vv)
        vh_denoised = bilateral_denoise(vh)

        vv_edge = extract_edge_map(vv_denoised)
        vh_edge = extract_edge_map(vh_denoised)

        # Stack channels
        stacked = np.stack([
            normalize(vv_denoised),
            normalize(vh_denoised),
            vv_edge,
            vh_edge
        ], axis=0)  # Shape: [4, H, W]

        temporal_images.append(stacked)

    temporal_images = np.stack(temporal_images, axis=0)  # Shape: [T=4, 4, H, W]

    # ---------- Temporal Aggregation ----------
    mean_img = np.mean(temporal_images, axis=0)
    std_img = np.std(temporal_images, axis=0)
    diff_img = temporal_images[3] - temporal_images[0]

    agg_stack = np.concatenate([mean_img, std_img, diff_img], axis=0)  # Shape: [12, H, W]

    # ---------- Downsampling ----------
    downsampled = np.stack([downsample(agg_stack[c], DOWNSAMPLED_SIZE) for c in range(agg_stack.shape[0])], axis=0)  # [12, 64, 64]

    # ---------- Neural Encoding Placeholder ----------
    # Flatten to 1D (pretend we passed through neural encoder)
    embedding = downsampled.flatten()[:1024]  # Pad or truncate
    if embedding.shape[0] < 1024:
        embedding = np.pad(embedding, (0, 1024 - embedding.shape[0]))

    embeddings.append(np.concatenate([[i], embedding]))

# ---------- Save Embeddings ----------
embeddings = np.array(embeddings)
np.savetxt(os.path.join(OUTPUT_DIR, 'sar_embeddings.csv'), embeddings, delimiter=',', fmt='%.6f')
print("✅ Embeddings saved to:", os.path.join(OUTPUT_DIR, 'sar_embeddings.csv'))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\xarray\backends\zarr.py:1811, in _get_open_params(store, mode, synchronizer, group, consolidated, consolidate_on_close, chunk_store, storage_options, zarr_version, use_zarr_fill_value_as_mask, zarr_format)
#    1810 try:
# -> 1811     zarr_root_group = zarr.open_consolidated(store, **open_kwargs)
#    1812 except (ValueError, KeyError):
#    1813     # ValueError in zarr-python 3.x, KeyError in 2.x.
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\zarr\convenience.py:1360, in open_consolidated(store, metadata_key, mode, **kwargs)
#    1359 # setup metadata store
# -> 1360 meta_store = ConsolidatedStoreClass(store, metadata_key=metadata_key)
#    1362 # pass through
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\zarr\storage.py:3046, in ConsolidatedMetadataStore.__init__(self, store, metadata_key)
#    3045 # retrieve consolidated metadata
# -> 3046 meta = json_loads(self.store[metadata_key])
#    3048 # check format of consolidated metadata
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\zarr\storage.py:1120, in DirectoryStore.__getitem__(self, key)
#    1119 else:
# -> 1120     raise KeyError(key)
#
# KeyError: '.zmetadata'
#
# During handling of the above exception, another exception occurred:
#
# GroupNotFoundError                        Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\xarray\backends\zarr.py:1815, in _get_open_params(store, mode, synchronizer, group, consolidated, consolidate_on_close, chunk_store, storage_options, zarr_version, use_zarr_fill_value_as_mask, zarr_format)
#    1814 try:
# -> 1815     zarr_root_group = zarr.open_group(store, **open_kwargs)
#    1816     emit_user_level_warning(
#    1817         "Failed to open Zarr store with consolidated metadata, "
#    1818         "but successfully read with non-consolidated metadata. "
#    (...)
#    1828         RuntimeWarning,
#    1829     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\zarr\hierarchy.py:1578, in open_group(store, mode, cache_attrs, synchronizer, path, chunk_store, storage_options, zarr_version, meta_array)
#    1577             raise ContainsArrayError(path)
# -> 1578         raise GroupNotFoundError(path)
#    1580 elif mode == "w":
#
# GroupNotFoundError: group not found at path ''
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 16
#      13 os.makedirs(OUTPUT_DIR, exist_ok=True)
#      15 # ---------- Load Data ----------
# ---> 16 ds = xr.open_zarr(ZARR_PATH)
#      17 data = ds['bands'].values  # shape: [B, T=4, C=2, H, W]
#      18 print("Data shape:", data.shape)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\xarray\backends\zarr.py:1535, in open_zarr(store, group, synchronizer, chunks, decode_cf, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, consolidated, overwrite_encoded_chunks, chunk_store, storage_options, decode_timedelta, use_cftime, zarr_version, zarr_format, use_zarr_fill_value_as_mask, chunked_array_type, from_array_kwargs, **kwargs)
#    1521     raise TypeError(
#    1522         "open_zarr() got unexpected keyword arguments " + ",".join(kwargs.keys())
#    1523     )
#    1525 backend_kwargs = {
#    1526     "synchronizer": synchronizer,
#    1527     "consolidated": consolidated,
#    (...)
#    1532     "zarr_format": zarr_format,
#    1533 }
# -> 1535 ds = open_dataset(
#    1536     filename_or_obj=store,
#    1537     group=group,
#    1538     decode_cf=decode_cf,
#    1539     mask_and_scale=mask_and_scale,
#    1540     decode_times=decode_times,
#    1541     concat_characters=concat_characters,
#    1542     decode_coords=decode_coords,
#    1543     engine="zarr",
#    1544     chunks=chunks,
#    1545     drop_variables=drop_variables,
#    1546     chunked_array_type=chunked_array_type,
#    1547     from_array_kwargs=from_array_kwargs,
#    1548     backend_kwargs=backend_kwargs,
#    1549     decode_timedelta=decode_timedelta,
#    1550     use_cftime=use_cftime,
#    1551     zarr_version=zarr_version,
#    1552     use_zarr_fill_value_as_mask=use_zarr_fill_value_as_mask,
#    1553 )
#    1554 return ds
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\xarray\backends\api.py:687, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     675 decoders = _resolve_decoders_kwargs(
#     676     decode_cf,
#     677     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)
#     683     decode_coords=decode_coords,
#     684 )
#     686 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 687 backend_ds = backend.open_dataset(
#     688     filename_or_obj,
#     689     drop_variables=drop_variables,
#     690     **decoders,
#     691     **kwargs,
#     692 )
#     693 ds = _dataset_from_backend_dataset(
#     694     backend_ds,
#     695     filename_or_obj,
#    (...)
#     705     **kwargs,
#     706 )
#     707 return ds
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\xarray\backends\zarr.py:1608, in ZarrBackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, group, mode, synchronizer, consolidated, chunk_store, storage_options, zarr_version, zarr_format, store, engine, use_zarr_fill_value_as_mask, cache_members)
#    1606 filename_or_obj = _normalize_path(filename_or_obj)
#    1607 if not store:
# -> 1608     store = ZarrStore.open_group(
#    1609         filename_or_obj,
#    1610         group=group,
#    1611         mode=mode,
#    1612         synchronizer=synchronizer,
#    1613         consolidated=consolidated,
#    1614         consolidate_on_close=False,
#    1615         chunk_store=chunk_store,
#    1616         storage_options=storage_options,
#    1617         zarr_version=zarr_version,
#    1618         use_zarr_fill_value_as_mask=None,
#    1619         zarr_format=zarr_format,
#    1620         cache_members=cache_members,
#    1621     )
#    1623 store_entrypoint = StoreBackendEntrypoint()
#    1624 with close_on_error(store):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\xarray\backends\zarr.py:732, in ZarrStore.open_group(cls, store, mode, synchronizer, group, consolidated, consolidate_on_close, chunk_store, storage_options, append_dim, write_region, safe_chunks, zarr_version, zarr_format, use_zarr_fill_value_as_mask, write_empty, cache_members)
#     707 @classmethod
#     708 def open_group(
#     709     cls,
#    (...)
#     725     cache_members: bool = True,
#     726 ):
#     727     (
#     728         zarr_group,
#     729         consolidate_on_close,
#     730         close_store_on_close,
#     731         use_zarr_fill_value_as_mask,
# --> 732     ) = _get_open_params(
#     733         store=store,
#     734         mode=mode,
#     735         synchronizer=synchronizer,
#     736         group=group,
#     737         consolidated=consolidated,
#     738         consolidate_on_close=consolidate_on_close,
#     739         chunk_store=chunk_store,
#     740         storage_options=storage_options,
#     741         zarr_version=zarr_version,
#     742         use_zarr_fill_value_as_mask=use_zarr_fill_value_as_mask,
#     743         zarr_format=zarr_format,
#     744     )
#     746     return cls(
#     747         zarr_group,
#     748         mode,
#    (...)
#     756         cache_members,
#     757     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\xarray\backends\zarr.py:1831, in _get_open_params(store, mode, synchronizer, group, consolidated, consolidate_on_close, chunk_store, storage_options, zarr_version, use_zarr_fill_value_as_mask, zarr_format)
#    1816             emit_user_level_warning(
#    1817                 "Failed to open Zarr store with consolidated metadata, "
#    1818                 "but successfully read with non-consolidated metadata. "
#    (...)
#    1828                 RuntimeWarning,
#    1829             )
#    1830         except missing_exc as err:
# -> 1831             raise FileNotFoundError(
#    1832                 f"No such file or directory: '{store}'"
#    1833             ) from err
#    1835 # but the user should still receive a DataTree whose root is the group they asked for
#    1836 if group and group != "/":
#
# FileNotFoundError: No such file or directory: 'D:\Eval.AI	rain\ssl4eos12_train_seasonal_data_000001.zarr'

# %%
# !pip install -U scikit-image
# Out:
# Requirement already satisfied: scikit-image in c:\users\dhina\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (0.22.0)
# Collecting scikit-image
#   Obtaining dependency information for scikit-image from https://files.pythonhosted.org/packages/5f/ee/c53a009e3997dda9d285402f19226fbd17b5b3cb215da391c4ed084a1424/scikit_image-0.25.2-cp310-cp310-win_amd64.whl.metadata
#   Downloading scikit_image-0.25.2-cp310-cp310-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.24 in c:\users\dhina\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-image) (1.26.3)
# Collecting scipy>=1.11.4 (from scikit-image)
#   Obtaining dependency information for scipy>=1.11.4 from https://files.pythonhosted.org/packages/d0/d2/f0683b7e992be44d1475cc144d1f1eeae63c73a14f862974b4db64af635e/scipy-1.15.2-cp310-cp310-win_amd64.whl.metadata
#   Downloading scipy-1.15.2-cp310-cp310-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ---------------------------------------- 60.8/60.8 kB ? eta 0:00:00
# Requirement already satisfied: networkx>=3.0 in c:\users\dhina\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-image) (3.2.1)
# Collecting pillow>=10.1 (from scikit-image)
#   Obtaining dependency information for pillow>=10.1 from https://files.pythonhosted.org/packages/14/81/d0dff759a74ba87715509af9f6cb21fa21d93b02b3316ed43bda83664db9/pillow-11.1.0-cp310-cp310-win_amd64.whl.metadata
#   Downloading pillow-11.1.0-cp310-cp310-win_amd64.whl.metadata (9.3 kB)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in c:\users\dhina\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-image) (2.34.0)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\dhina\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-image) (2024.2.12)
# Requirement already satisfied: packaging>=21 in c:\users\dhina\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-image) (23.2)
# Collecting lazy-loader>=0.4 (from scikit-image)
#   Obtaining dependency information for lazy-loader>=0.4 from https://files.pythonhosted.org/packages/83/60/d497a310bde3f01cb805196ac61b7ad6dc5dcf8dce66634dc34364b20b4f/lazy_loader-0.4-py3-none-any.whl.metadata
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Downloading scikit_image-0.25.2-cp310-cp310-win_amd64.whl (12.8 MB)
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    - -------------------------------------- 0.4/12.8 MB 8.1 MB/s eta 0:00:02
#    -- ------------------------------------- 0.8/12.8 MB 9.7 MB/s eta 0:00:02
#    --- ------------------------------------ 1.1/12.8 MB 7.4 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.3/12.8 MB 6.8 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.6/12.8 MB 7.8 MB/s eta 0:00:02
#    ------ --------------------------------- 1.9/12.8 MB 7.2 MB/s eta 0:00:02
#    ------- -------------------------------- 2.4/12.8 MB 7.1 MB/s eta 0:00:02
#    -------- ------------------------------- 2.6/12