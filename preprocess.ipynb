# %% [markdown]
# # Dimension of S1GRD

# %%
import xarray as xr
ds = xr.open_zarr(r'data/SSL4EO-S12-v1.1/train/S1GRD/ssl4eos12_train_seasonal_data_000001.zarr')  # load xarray dataset
data = ds.bands.values  # load numpy array with dims [B, T, C, H, W]
print(ds['bands'].shape)
# Out:
# (64, 4, 2, 264, 264)

# %%
import os
import zipfile

# Define path
base_dir = r"D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD"

# List all .zip files in the folder
zip_files = [f for f in os.listdir(base_dir) if f.endswith('.zarr.zip')]

for zip_file in zip_files:
    zip_path = os.path.join(base_dir, zip_file)
    extract_folder_name = zip_file.replace('.zip', '')  # Get .zarr folder name
    extract_path = os.path.join(base_dir, extract_folder_name)

    # Skip if already extracted
    if os.path.exists(extract_path):
        print(f"[✓] Already extracted: {extract_folder_name}")
        continue

    # Extract
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)
        print(f"[+] Extracted: {zip_file} → {extract_path}")
# Out:
# [+] Extracted: ssl4eos12_train_seasonal_data_000001.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000001.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000002.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000002.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000003.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000003.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000004.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000004.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000005.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000005.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000006.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000006.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000007.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000007.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000008.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000008.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000009.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000009.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000010.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000010.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000011.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000011.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000012.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000012.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000013.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000013.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000014.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000014.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000015.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000015.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000016.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000016.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000017.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000017.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000018.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000018.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000019.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000019.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000020.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000020.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000021.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000021.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000022.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000022.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000023.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000023.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000024.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000024.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000025.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000025.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000026.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000026.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000027.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000027.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000028.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000028.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000029.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000029.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000030.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000030.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000031.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000031.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000032.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000032.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000033.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000033.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000034.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000034.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000035.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000035.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000036.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000036.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000037.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000037.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000038.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000038.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000039.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000039.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000040.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000040.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000041.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000041.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000042.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000042.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000043.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000043.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000044.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000044.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000045.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000045.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000046.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000046.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000047.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000047.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000048.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000048.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000049.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000049.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000050.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000050.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000051.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000051.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000052.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000052.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000053.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000053.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000054.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000054.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000055.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000055.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000056.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000056.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000057.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000057.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000058.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000058.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000059.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000059.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000060.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000060.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000061.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000061.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000062.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000062.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000063.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000063.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000064.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000064.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000065.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000065.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000066.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000066.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000067.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000067.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000068.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000068.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000069.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000069.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000070.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000070.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000071.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000071.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000072.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000072.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000073.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000073.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000074.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000074.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000075.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000075.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000076.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000076.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000077.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000077.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000078.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000078.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000079.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000079.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000080.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000080.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000081.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000081.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000082.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000082.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000083.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000083.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000084.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000084.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000085.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000085.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000086.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000086.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000087.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000087.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000088.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000088.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000089.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000089.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000090.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000090.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000091.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000091.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000092.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000092.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000093.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000093.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000094.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000094.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000095.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000095.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000096.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000096.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000097.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000097.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000098.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000098.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000099.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000099.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000100.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000100.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000101.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000101.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000102.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000102.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000103.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000103.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000104.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000104.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000105.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000105.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000106.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000106.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000107.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000107.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000108.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000108.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000109.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000109.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000110.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000110.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000111.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000111.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000112.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000112.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000113.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000113.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000114.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000114.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000115.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000115.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000116.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000116.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000117.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000117.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000118.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000118.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000119.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000119.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000120.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000120.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000121.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000121.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000122.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000122.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000123.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000123.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000124.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000124.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000125.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000125.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000126.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000126.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000127.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000127.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000128.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000128.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000129.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000129.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000130.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000130.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000131.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000131.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000132.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000132.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000133.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000133.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000134.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000134.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000135.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000135.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000136.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000136.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000137.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000137.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000138.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_
zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000341.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000341.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000342.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000342.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000343.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000343.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000344.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000344.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000345.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000345.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000346.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000346.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000347.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000347.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000348.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000348.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000349.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000349.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000350.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000350.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000351.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000351.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000352.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000352.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000353.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000353.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000354.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000354.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000355.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000355.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000356.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000356.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000357.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000357.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000358.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000358.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000359.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000359.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000360.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000360.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000361.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000361.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000362.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000362.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000363.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000363.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000364.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000364.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000365.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000365.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000366.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000366.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000367.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000367.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000368.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000368.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000369.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000369.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000370.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000370.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000371.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000371.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000372.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000372.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000373.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000373.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000374.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000374.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000375.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000375.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000376.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000376.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000377.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000377.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000378.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000378.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000379.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000379.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000380.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000380.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000381.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000381.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000382.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000382.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000383.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000383.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000384.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000384.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000385.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000385.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000386.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000386.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000387.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000387.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000388.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000388.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000389.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000389.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000390.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000390.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000391.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000391.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000392.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000392.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000393.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000393.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000394.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000394.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000395.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000395.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000396.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000396.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000399.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000399.zarr
# [+] Extracted: ssl4eos12_train_seasonal_data_000400.zarr.zip → D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000400.zarr

# %%
import xarray as xr
import numpy as np
import cv2

# Load Zarr
zarr_path = r'D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000001.zarr'
ds = xr.open_zarr(zarr_path)
bands = ds['bands'].values  # Shape: (64, 4, 2, 264, 264)

print("Loaded data shape:", bands.shape)

# Denoising function for SAR
def bilateral_denoise(image):
    return cv2.bilateralFilter(image.astype(np.float32), d=9, sigmaColor=75, sigmaSpace=75)

# Preallocate array for denoised output
denoised = np.zeros_like(bands)

# Apply bilateral filter to all [N=64, T=4, C=2]
for n in range(bands.shape[0]):
    for t in range(bands.shape[1]):
        for c in range(bands.shape[2]):
            denoised[n, t, c] = bilateral_denoise(bands[n, t, c])
    print(f"[✓] Finished sample {n+1}/64")

print("✅ Denoising complete. Final shape:", denoised.shape)
# Out:
# Loaded data shape: (64, 4, 2, 264, 264)
# [✓] Finished sample 1/64
# [✓] Finished sample 2/64
# [✓] Finished sample 3/64
# [✓] Finished sample 4/64
# [✓] Finished sample 5/64
# [✓] Finished sample 6/64
# [✓] Finished sample 7/64
# [✓] Finished sample 8/64
# [✓] Finished sample 9/64
# [✓] Finished sample 10/64
# [✓] Finished sample 11/64
# [✓] Finished sample 12/64
# [✓] Finished sample 13/64
# [✓] Finished sample 14/64
# [✓] Finished sample 15/64
# [✓] Finished sample 16/64
# [✓] Finished sample 17/64
# [✓] Finished sample 18/64
# [✓] Finished sample 19/64
# [✓] Finished sample 20/64
# [✓] Finished sample 21/64
# [✓] Finished sample 22/64
# [✓] Finished sample 23/64
# [✓] Finished sample 24/64
# [✓] Finished sample 25/64
# [✓] Finished sample 26/64
# [✓] Finished sample 27/64
# [✓] Finished sample 28/64
# [✓] Finished sample 29/64
# [✓] Finished sample 30/64
# [✓] Finished sample 31/64
# [✓] Finished sample 32/64
# [✓] Finished sample 33/64
# [✓] Finished sample 34/64
# [✓] Finished sample 35/64
# [✓] Finished sample 36/64
# [✓] Finished sample 37/64
# [✓] Finished sample 38/64
# [✓] Finished sample 39/64
# [✓] Finished sample 40/64
# [✓] Finished sample 41/64
# [✓] Finished sample 42/64
# [✓] Finished sample 43/64
# [✓] Finished sample 44/64
# [✓] Finished sample 45/64
# [✓] Finished sample 46/64
# [✓] Finished sample 47/64
# [✓] Finished sample 48/64
# [✓] Finished sample 49/64
# [✓] Finished sample 50/64
# [✓] Finished sample 51/64
# [✓] Finished sample 52/64
# [✓] Finished sample 53/64
# [✓] Finished sample 54/64
# [✓] Finished sample 55/64
# [✓] Finished sample 56/64
# [✓] Finished sample 57/64
# [✓] Finished sample 58/64
# [✓] Finished sample 59/64
# [✓] Finished sample 60/64
# [✓] Finished sample 61/64
# [✓] Finished sample 62/64
# [✓] Finished sample 63/64
# [✓] Finished sample 64/64
# ✅ Denoising complete. Final shape: (64, 4, 2, 264, 264)

# %%
import xarray as xr
import numpy as np

# Load Zarr file (adjust filename as needed)
zarr_path = r'D:\IVP _ project\data\SSL4EO-S12-v1.1\train\S1GRD\ssl4eos12_train_seasonal_data_000001.zarr'
ds = xr.open_zarr(zarr_path)

# Select a single sample (sample_index = 0)
sample_index = 0
sar_cube = ds.bands[sample_index].values  # shape: [T=4, C=2, H=264, W=264]
print("Shape of one SAR cube:", sar_cube.shape)
# Out:
# Shape of one SAR cube: (4, 2, 264, 264)

# %%
import cv2
from skimage.transform import resize

def bilateral_denoise(image):
    return cv2.bilateralFilter(image.astype(np.float32), d=9, sigmaColor=75, sigmaSpace=75)

def apply_clahe(image):
    norm = cv2.normalize(image, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    return clahe.apply(norm)

def sobel_edges(image):
    grad_x = cv2.Sobel(image, cv2.CV_32F, 1, 0, ksize=3)
    grad_y = cv2.Sobel(image, cv2.CV_32F, 0, 1, ksize=3)
    magnitude = cv2.magnitude(grad_x, grad_y)
    return magnitude

# %%
processed = []

for t in range(sar_cube.shape[0]):  # T = 4 seasons
    vv = sar_cube[t, 0]  # VV polarization
    vh = sar_cube[t, 1]  # VH polarization

    vv_denoised = bilateral_denoise(vv)
    vh_denoised = bilateral_denoise(vh)

    vv_clahe = apply_clahe(vv_denoised)
    edge_map = sobel_edges(vv_clahe)

    # Stack: [vv_denoised, vh_denoised, vv_clahe, edge_map]
    processed.append(np.stack([vv_denoised, vh_denoised, vv_clahe, edge_map], axis=0))

processed = np.stack(processed)  # shape: [T=4, C=4, H=264, W=264]
print("Processed shape:", processed.shape)
# Out:
# Processed shape: (4, 4, 264, 264)

# %%
mean_img = np.mean(processed, axis=0)           # [C=4, H, W]
std_img = np.std(processed, axis=0)             # [C=4, H, W]
diff_img = processed[-1] - processed[0]         # [C=4, H, W]

temporal_stack = np.concatenate([mean_img, std_img, diff_img], axis=0)  # [C=12, H, W]
print("Temporal aggregated shape:", temporal_stack.shape)
# Out:
# Temporal aggregated shape: (12, 264, 264)

# %%
def downsample(image, target_shape=(64, 64)):
    return resize(image, target_shape, mode='reflect', preserve_range=True, anti_aliasing=True)

downsampled = np.stack([downsample(temporal_stack[c]) for c in range(temporal_stack.shape[0])])
# Shape: [C=12, H=64, W=64]
print("Final downsampled shape:", downsampled.shape)
# Out:
# Final downsampled shape: (12, 64, 64)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class CNNTransformerEncoder(nn.Module):
    def __init__(self, input_channels=27, compressed_dim=1024):
        super(CNNTransformerEncoder, self).__init__()

        # CNN Encoder to extract spatial features
        self.cnn = nn.Sequential(
            nn.Conv2d(input_channels, 64, kernel_size=3, stride=2, padding=1),  # [B, 64, 132, 132]
            nn.BatchNorm2d(64),
            nn.ReLU(),

            nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1),  # [B, 128, 66, 66]
            nn.BatchNorm2d(128),
            nn.ReLU(),

            nn.Conv2d(128, 256, kernel_size=3, stride=2, padding=1),  # [B, 256, 33, 33]
            nn.BatchNorm2d(256),
            nn.ReLU(),

            nn.Conv2d(256, 512, kernel_size=3, stride=2, padding=1),  # [B, 512, 17, 17]
            nn.BatchNorm2d(512),
            nn.ReLU(),
        )

        # Flatten spatial dimensions to transformer tokens
        self.proj = nn.Linear(512, 128)
        self.transformer = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model=128, nhead=8, dim_feedforward=256, batch_first=True),
            num_layers=2
        )

        # Compress to 1024 features
        self.fc = nn.Linear(128, compressed_dim)

    def forward(self, x):
        x = self.cnn(x)  # [B, 512, 17, 17]
        B, C, H, W = x.shape
        x = x.view(B, C, H * W).permute(0, 2, 1)  # [B, 289, 512]
        x = self.proj(x)  # [B, 289, 128]
        x = self.transformer(x)  # [B, 289, 128]
        x = x.mean(dim=1)  # [B, 128]
        compressed = self.fc(x)  # [B, 1024]
        return compressed

# Example usage and saving to CSV
if __name__ == '__main__':
    import numpy as np
    import pandas as pd

    # Simulated preprocessed datacube [B, C=27, H=264, W=264]
    batch_size = 1
    datacube_ids = [f"cube_{i:05d}" for i in range(batch_size)]
    dummy_input = torch.randn(batch_size, 27, 264, 264)

    model = CNNTransformerEncoder()
    model.eval()

    with torch.no_grad():
        embeddings = model(dummy_input).numpy()  # [B, 1024]

    # Save to CSV with first column as datacube ID
    df = pd.DataFrame(embeddings, columns=[f"f{i+1}" for i in range(1024)])
    df.insert(0, "datacube_id", datacube_ids)
    df.to_csv("compressed_embeddings.csv", index=False)

    print("Compressed embeddings saved to 'compressed_embeddings.csv'")
# Out:
# Compressed embeddings saved to 'compressed_embeddings.csv'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms
import numpy as np

# Simulated single preprocessed datacube: [C=12, H=64, W=64]
# Normally, you’d load this from your Zarr processing pipeline
preprocessed_sample = torch.randn(12, 64, 64)  # Placeholder

# Move to batch format
preprocessed_sample = preprocessed_sample.unsqueeze(0)  # [1, 12, 64, 64]

# ------------------------------------------------------------
# Data Augmentation for SimCLR
# ------------------------------------------------------------
augmentation = transforms.Compose([
    transforms.RandomResizedCrop(64, scale=(0.8, 1.0)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomApply([transforms.GaussianBlur(3)], p=0.5),
])

def apply_augments(image_tensor):
    # Apply torchvision transforms to each channel independently
    channels = []
    for c in image_tensor.squeeze(0):  # remove batch dim
        pil = transforms.ToPILImage()(c.unsqueeze(0))  # Convert to PIL
        aug = augmentation(pil)
        tensor = transforms.ToTensor()(aug).squeeze(0)  # Back to tensor
        channels.append(tensor)
    return torch.stack(channels).unsqueeze(0)  # Add batch dim back

# Generate (d1, d2)
d1 = apply_augments(preprocessed_sample)
d2 = apply_augments(preprocessed_sample)
# Out:
# C:\Users\Dhina\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\torch\utils\_pytree.py:185: FutureWarning: optree is installed but the version is too old to support PyTorch Dynamo in C++ pytree. C++ pytree support is disabled. Please consider upgrading optree using `python3 -m pip install --upgrade 'optree>=0.13.0'`.
#   warnings.warn(
